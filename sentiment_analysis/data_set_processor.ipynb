# %%
import os
import glob

import nltk
import string

import gzip

# %%
# load data from datasets

data_categories = ['books', 'dvd', 'electronics', 'kitchen_&_housewares']
review_categories = ['positive', 'negative', 'unlabeled']

data_dir = "sorted_data_acl"

# load data
def review_data_load():
    data_map = {data_category: {} for data_category in data_categories}
    
    for data_category in data_categories:
        for review_category in review_categories:
            file_path = os.path.join(data_dir, data_category, f"{review_category}.review")
            
            if os.path.exists(file_path):               
                try:
                    with open(file_path, 'r') as file:
                        data_map[data_category][review_category] = file.read()
                except UnicodeDecodeError as e:
                    with gzip.open(file_path, 'rt', encoding='utf-8') as file:
                        data_map[data_category][review_category] = file.read()
            else:
                data_map[data_category][review_category] = None
    
    return data_map

data_map = review_data_load()

#check data
def check_loaded_data():
    for data_category, review_categories_data in data_map.items():
        for review, review_category_data in review_categories_data.items():
            print(f"{data_category} has {review} type {type(review_category_data)} size {len(review_category_data) if review_category_data else 0}")

check_loaded_data()
# Out:
# books has positive type <class 'str'> size 1510847
# books has negative type <class 'str'> size 1538070
# books has unlabeled type <class 'str'> size 8851303
# dvd has positive type <class 'str'> size 1695767
# dvd has negative type <class 'str'> size 1588827
# dvd has unlabeled type <class 'str'> size 58727310
# electronics has positive type <class 'str'> size 1104976
# electronics has negative type <class 'str'> size 1113470
# electronics has unlabeled type <class 'str'> size 14584186
# kitchen_&_housewares has positive type <class 'str'> size 1018947
# kitchen_&_housewares has negative type <class 'str'> size 1019913
# kitchen_&_housewares has unlabeled type <class 'str'> size 17079518

# %%
# load xml nodes from files to data structures
import xml.etree.ElementTree as ET
import re

from fractions import Fraction
from enum import Enum

class Review:
    def __init__(self, rating, review_text, helpfull, title):
        self.rating = rating
        self.review_text = review_text
        self.title = title

        if helpfull is None or " of " not in helpfull:
            self.helpfull = None
        else:
            numerator, denominator = helpfull.split(" of ")
            numerator = int(numerator)
            denominator = int(denominator)
            self.helpfull = Fraction(int(numerator), int(denominator))
    
    def __repr__(self):
        return f"Review(rating={self.rating}, helpfull={self.helpfull if self.helpfull is not None else ""}, title={self.title}, review_text={self.review_text})"

def wrap_with_root(xml_string):
    return f"<root>{xml_string}</root>"

def parse_review_XML_text_to_structures(reviews_text):
    wrapped_text = wrap_with_root(reviews_text)
    try:
        root = ET.fromstring(wrapped_text)
    except Exception as e:
        print(e)
        print(wrapped_text[57162753:57162793])
    
    reviews = []
    
    print(f"Number of child elements: {len(root)}")
    
    for review in root.findall('review'):
        helpful = review.find('helpful').text
        rating = int(float(review.find('rating').text))
        title = review.find('title').text
        review_text = review.find('review_text').text

        reviews.append(Review(rating, review_text, helpful, title))

    print(f"It {len(reviews_text)} parsed to {len(reviews)} reviews")
    return reviews

def parse_data_to_reviews(data_map):
    reviews_map = {}
    
    for data_category, review_categories_data in data_map.items():
        for review_category, review_category_data in review_categories_data.items():
            print(f"Parse {review_category} {data_category}")
            review_category_data = re.sub(r'[\x00-\x1F\x7F]', '', review_category_data)

            outer = reviews_map.get(data_category, {})
            outer[review_category] = parse_review_XML_text_to_structures(review_category_data.replace('&', '&amp;'))
            reviews_map[data_category] = outer
    
    return reviews_map

reviews_map = parse_data_to_reviews(data_map)

#check data
def check_parsed_data():
    for data_category, review_categories_data in reviews_map.items():
        for review_category, review_category_data in review_categories_data.items():
            print(f"{data_category} has {review_category} type {type(review_category_data)} size {len(review_category_data)}")
            #print(review_category_data[:2])
            #print(review_category_data[-2:])

check_parsed_data()
# Out:
# Parse positive books
# Number of child elements: 1000
# It 1474257 parsed to 1000 reviews
# Parse negative books
# Number of child elements: 1000
# It 1500849 parsed to 1000 reviews
# Parse unlabeled books
# Number of child elements: 6000
# It 8629089 parsed to 6000 reviews
# Parse positive dvd
# Number of child elements: 1000
# It 1658273 parsed to 1000 reviews
# Parse negative dvd
# Number of child elements: 1000
# It 1551839 parsed to 1000 reviews
# Parse unlabeled dvd
# Number of child elements: 34741
# It 57429114 parsed to 34741 reviews
# Parse positive electronics
# Number of child elements: 1000
# It 1068133 parsed to 1000 reviews
# Parse negative electronics
# Number of child elements: 1000
# It 1076844 parsed to 1000 reviews
# Parse unlabeled electronics
# Number of child elements: 13153
# It 14102103 parsed to 13153 reviews
# Parse positive kitchen_&_housewares
# Number of child elements: 1000
# It 991226 parsed to 1000 reviews
# Parse negative kitchen_&_housewares
# Number of child elements: 1000
# It 992533 parsed to 1000 reviews
# Parse unlabeled kitchen_&_housewares
# Number of child elements: 16785
# It 16617356 parsed to 16785 reviews
# books has positive type <class 'list'> size 1000
# books has negative type <class 'list'> size 1000
# books has unlabeled type <class 'list'> size 6000
# dvd has positive type <class 'list'> size 1000
# dvd has negative type <class 'list'> size 1000
# dvd has unlabeled type <class 'list'> size 34741
# electronics has positive type <class 'list'> size 1000
# electronics has negative type <class 'list'> size 1000
# electronics has unlabeled type <class 'list'> size 13153
# kitchen_&_housewares has positive type <class 'list'> size 1000
# kitchen_&_housewares has negative type <class 'list'> size 1000
# kitchen_&_housewares has unlabeled type <class 'list'> size 16785

# %%
# Check spells, remove special characters, expanding contractions etc...
import contractions

from spellchecker import SpellChecker
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob

from IPython.display import clear_output

# pip install spellchecker, pyspellchecker
# python3 -m nltk.downloader all
#nltk.download('wordnet')
#nltk.download('omw-1.x')
#nltk.download('stopwords')
#nltk.download('punkt')

spell = SpellChecker()
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

to_remove_punctuation = True
to_convert_to_lowercase = True
to_remove_numbers = False
to_remove_extra_whitespace = True
to_correct_spelling = False
to_remove_stop_words = True
to_stem_words = False
to_lemmatize_words = True
to_remove_specs = True
to_expand_contractions = True

# Punctuation often doesn't add much meaning for many NLP tasks and can be removed.
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

#Converting all text to lowercase ensures that words are treated uniformly.
def convert_to_lowercase(text):
    return text.lower()

# In some cases, numbers might not be relevant.
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# Extra whitespace and newline characters should be removed or normalized.
def remove_extra_whitespace(text):
    return ' '.join(text.split())

# Stop words (common words that don’t add much meaning) can be removed.
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def remove_stop_words(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

def correct_spelling(text): # need to improve performance
    words = text.split()
    corrected_words = []

    for word in words:
        correct_word = spell.candidates(word)
        corrected_words.append(word if correct_word is None else list(correct_word)[0])
    
    #print(corrected_words)
    return ' '.join(corrected_words)

def correct_spelling2(text): # need to improve performance
    b = TextBlob(text)
    return b.correct().string

# Stemming reduces words to their root form.
def stem_words(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)

# Lemmatization reduces words to their base or dictionary form, usually providing better results than stemming.
def lemmatize_words(text):
    words = word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# remove URLs
def remove_urls(text):
    return re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

# remove emails
def remove_emails(text):
    return re.sub(r'\b[\w.%+-]+@[\w.-]+\.[a-zA-Z]{2,6}\b', '', text)

# remove special characters
def remove_special_characters(text):
    return re.sub(r'[^\w\s]', '', text)

def remove_specs(text):
    return remove_special_characters(remove_emails(remove_urls(text)))

# expanding contractions to full forms for more consistent analysis
def expand_contractions(text):
    return contractions.fix(text)

clean_function_list = [
    (to_remove_extra_whitespace, remove_extra_whitespace),
    (to_remove_punctuation, remove_punctuation),
    (to_correct_spelling, correct_spelling2),
    (to_expand_contractions, expand_contractions),
    (to_remove_stop_words, remove_stop_words),
    (to_stem_words, stem_words),
    (to_lemmatize_words, lemmatize_words),
    (to_convert_to_lowercase, convert_to_lowercase),
    (to_remove_numbers, remove_numbers),
    (to_remove_specs, remove_specs)
]

def clean_data(text):
    for to_do_clean, clean_func in clean_function_list:
        if not text:
            return ''
        if to_do_clean:
            text = clean_func(text)

    return text

reviews_map_cleaned = reviews_map.copy()

def clean_reviews():
    for data_category, review_categories_data in reviews_map_cleaned.items():
        for review_category, review_category_data in review_categories_data.items():
            clear_output()
            print(f"{data_category} {review_category} started")
            counter = 0
            
            for review in review_category_data:
                review.review_text = clean_data(review.review_text)
                review.title = clean_data(review.title)
                
                counter += 1
                if counter == 1000:
                    counter = 0
                    print('Next hundred reviews were cleaned')
            
            print(f"{data_category} {review_category} finished")

clean_reviews()
# Out:
# kitchen_&_housewares unlabeled started
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# Next hundred reviews were cleaned
# kitchen_&_housewares unlabeled finished

# %%
def check_clean_data():
    for data_category, review_categories_data in reviews_map_cleaned.items():
        for review_category, review_category_data in review_categories_data.items():
            print(f"{data_category} has {review_category} type {type(review_category_data)} size {len(review_category_data)}")
            print(review_category_data[:2])
            print(review_category_data[-2:])

check_clean_data()
# Out:
# books has positive type <class 'list'> size 1000
# [Review(rating=5, helpfull=0, title=one best crichton novel, review_text=sphere michael crichton excellent novel certainly hardest put crichton novel read story revolves around man named norman johnson johnson psychologist travel 4 civilian remote location pacific ocean help navy top secret mission quickly learn ocean half mile long spaceship civilian travel center 1000 foot ocean live searching statecraft joined 5 navy personal help run operation however surface typhoid come support ship surface must leave team ten stuck 1000 foot surface ocean day sea find statecraft actually american ship explored black hole brought back strange thing back earththis novel research crichton novel still lot information random thing law partial pressure behavior analysis would strongly recommend book), Review(rating=4, helpfull=34/41, title=medicine future, review_text=z accomplished heart surgeon field cardiac transplantation describes combined complementary medicine eg cyanosis reflexology message acupuncture etc orthodox western medicine excellent forward mean finish interesting epilogue containing overview complementary medicine technique bulk book contains story patient z treated using revolutionary way cardiologist great interest combining western medicine complementary medicine reason bought book however book bit boring read also bit disappointment nevertheless interested new medicine think medicine new millennium want read book)]
# [Review(rating=2, helpfull=, title=buy generic one, review_text=bought several came fancy blister others coushing bag stay away sure buying sealed one physical design lot differenti give generic two star work give four star original others reviewer said little difficult remove card), Review(rating=2, helpfull=5/6, title=know, review_text=bought easy transfer picture digital camera sd memory card anywhere home sometimes people memory card xd memory stickfirst disappointed flimsy plastic design size would ok workedit read sd card menetioned people review hard insert take card scared card get scratch ruined whenever wish bought reading amazon reviewsits useless lost get sd card work scared frequent use flimsy design)]
# electronics has unlabeled type <class 'list'> size 13153
# [Review(rating=5, helpfull=19/24, title=power ups everything need know, review_text=first want power ups good reason 1 never want machine go incorrectly blackout 2 want work clean power 3 want monitor pc power 4 want prevent pc damaged due power problem like lighting strike want surge protection first rule ups never trust insurance claim get pc insured elsewhere company tendency support insurance claim pc running high specification six usb device lcd monitor printer ethernet equipment everything time never gone 325w usage average 250w 300w managing high spec game lot background task even though 400w power supply unit psu upgrading 500w psu better quality model way monitor many watts use ups software hardware question need ask many watt using short answer know install ups software tell many watt use appears way monitor wattage time need estimate would say highend domestic pc server would use 300w max one every device think turned soon add thing like another pc several printer several monitor start overload 325w ups brings u first thing need learn ups overloading balancing overload feature warning system turn overloaded ups capacity overloading two thing theory eventually damage ups void warranty ups 325w 800w 1000w even greater model home network use one pc setup honest probably going get ups per pc setup rather expensive bigger ups network check ups rating ups choose depends much want load next thing need check ups come usb connection big plus mean control pc ups come software ups feature load stuff like turning ups sound alarm controlling ups handle blackout long us battery shutdown hibernation sound alarm run self test data collection monitoring notification sensitivity setting ups come usb connection software probably looking ups designed computer use rather ups noncomputer equipment ups led indicator tell status unit next thing understand testing ups done breaking box connecting main plugging pc turning house power circuit breaker must charge ups first read instruction usually must attach battery ups plug firmly wait using perform test using software first consider trying simulate blackout home see pc stay usually ups programmed shutdown pc blackout last second nearly ups model usb connection customized shutdown event long pc hold ups battery ups device allow connect modem phone line device run phone line modem important power surge ups protection damage pc unprotected phone line running modem usually run pc somehow nasty problem degree security ups provide function going provide 100 surge protection pc online networking ups pc another pc without ups also increase risk surge protection problem recommend network ups pc nonups pc unless surge protection warranty issue one last thing ups input region ups surge protection input region surge protected also model battery need replaced year end using lot everything need know ups choose one basically downloading technical spec ups making sure provides need two top brand apc belkin), Review(rating=5, helpfull=5/8, title=good product, review_text=bought backup imac g5 got wife christmas apc since 1996 depended keep system running smoothly typical voltage fluctuation areathe overall product well designed good value moneyim sure powerchute software updated run mac tiger howvever install itsteve reis)]
# [Review(rating=5, helpfull=1, title=waste money cf gps receiver, review_text=awesome product easy use excellent signal level use dell axim x50v connected laptop via pcmcia cf reader worked without problem tried microsoft pocket street 2005 microsoft street trip 2005 tomtom navigator 50dont waste money gps cf card perfect choice), Review(rating=5, helpfull=8/9, title=tiny toy really work, review_text=dell x50v pda running microsoft ce used microsoft pocket streets 2005 delorme handheld 2005 work perfectly gm270u receiver tiny fit naturally dell x50v use inside car astonishing antenna required carry outdoor activity man tell staff cool regret compared hundred thousand dollar gps system gps receiver give bargin price)]
# kitchen_&_housewares has positive type <class 'list'> size 1000
# [Review(rating=5, helpfull=, title=perfectly fit book atmosphere, review_text=unfamiliar series unfortunate events book detail absurdly tragic life fictional baudelaire orphan struggle overcome adversity adversity adversity ad infinitum hovering background tragedy occasional brief glimpse happiness distant cousin scheming greedy conniving ruthless cousin countgiven concept story poster fit perfectly orphan standing together otherwise alone middle shadow count casting gloom upon perfect fit casting jim carrey count), Review(rating=5, helpfull=1, title=doggy fueds neighbor, review_text=absolutely love product neighbor four little yippers shepardchow mix antogonized yipping side fence hung device side fence noise keep neighbor dog picking argument dog barking fighting ceased surrounding neighbor well get good night sleep)]
# [Review(rating=4, helpfull=0, title=pleased, review_text=looking high low new flatware set minute seen ampquotnon stopampquot needless sayi pleased), Review(rating=5, helpfull=1, title=love, review_text=three dog fur endless come home work start roomba voila dog hair pick stuff vacuum ever)]
# kitchen_&_housewares has negative type <class 'list'> size 1000
# [Review(rating=2, helpfull=, title=keep yappy cairn barking, review_text=look away spray emitsand bark againit also work 100 timeand sure fill seems work fairly well right either many spray supposed working longit work well small dog persistent barker terriers stubborn care getting sprayed guess), Review(rating=1, helpfull=1, title=buyer beware, review_text=read review product site decided go ahead give collar shot despite problem reviewer encountered ordered three product site arrived single one worked completely useless despite trying everything reviewer manufacturer suggested product completely useless although contacted manufacturer product defect would still like buyer aware purchasing product website product work returned refund even exchanged thus credit card still billed dog still barking may get stuck product worthless)]
# [Review(rating=1, helpfull=1, title=love oxo product huge disappointment, review_text=mine broke 3rd use need say anymore), Review(rating=2, helpfull=1/2, title=buy, review_text=worked great first couple time keep charger 24 hour realizing problem battery work 10 minute time basically worthless)]
# kitchen_&_housewares has unlabeled type <class 'list'> size 16785
# [Review(rating=5, helpfull=, title=excellent alternative shock collar, review_text=old beagle decided dotage would bark ever get way becoming intolerable barking hour night disturbing everyone around extremely fragile heart condition felt shock collar could kill admit skeptical spray collar desperate anyone owned beagle know difficult best train tried collar happy report work tallys barking returned normal levelwhich infrequent happened quickly within day followed direction box important good result promise work every dog worked well ourswithout resorting shock think hang collar dog expect work although ocassionaly tally refresh training feel important training outlined instruction get result fairly quickly quite satisfied product), Review(rating=5, helpfull=1, title=best dog behavior modification device, review_text=premier collar best solution help dog restrain barking without injury learned within day walk stop barking dog wearing collar want use shock method groomer told premier citronella collar aid training got good result)]
# [Review(rating=5, helpfull=4/5, title=great little work horse makes thing hot chocolate, review_text=got little machine first came market fan presweetened powdered hot chocolate mix one put water milk cup stir use old fashion hersheys baking powder come brown one add powder milk salt vanilla extract sugar pain neck cook batch stove well machine came got right away throw ingedients let go wow hot chocolate taste even better believe stiring motion ingredient properly stired secret along gentle heating extra bowl replug heat find unplug machine replug reheat machine year problem break down ill get another one thing crazy bowl removable put whole machine sink clean cocomotion great warmed concoction like hot apple cider capuccino general food international coffee doctor use extra sugar flavored extract chocolate use milk come great used cocomotion buy noticed big price difference one store small appliance say worth 3540 dollar find cheaper hot chocolate lover way anyone remember big disco song called cocomotion think every time use machine mr coffee advertise machine use music suggestion), Review(rating=5, helpfull=4/5, title=love, review_text=mom bought christmas well name tag positive actually 3 young daughter lol almost went ebay pile glad kept great poured milk added nestle powder started made sandwich everyone lunch time done hot cocoa nuker microwave use quite often reason always made hot cocoa stove constantly stirring make sure well mixedno even using cocoa powder like nestle cocomotion mixed milk powder perfectly right temp even drinking hot cocoa lol sure could drink also like spiced tea allhmmm feel experiment coming lol read ball bearing came couple people unit hope happen mine ill buying another cocomotion putting away case mine loses bearing lol well worth)]

# %%
# prepare Pandas dataset
import pandas as pd
import concurrent.futures
import multiprocessing

from nltk.corpus import words
nltk.download('words')

valid_words = set(words.words())

# to check if a review text has a sufficient number of valid words
def is_meaningful_review(review_text, min_valid_words=5):
    word_list = review_text.split()
    valid_word_count = sum(1 for word in word_list if word in valid_words)
    return valid_word_count >= min_valid_words  

# to estimate review
class ReviewCategory(Enum):
    POS = 1
    NEG = 2
    UNDEF = 3
    
def mark_review(review, review_category):
    if review_category == 'positive':
        return ReviewCategory.POS
    if review_category == 'negative':
        return ReviewCategory.NEG

    if review.rating > 3:
        return ReviewCategory.POS
    if review.rating < 3:
        return ReviewCategory.NEG
    
    return ReviewCategory.UNDEF

def spelling_correction(text):
    b = TextBlob(text)
    return b.correct().string        

def spelling_corrections(texts):
    results = [spelling_correction(text) for text in texts]
    print('Next chunk of corrections was finished')
    return results

def make_spelling_correction(texts):
    chunk_size = 1000
    chunks = [texts[i:i + chunk_size] for i in range(0, len(texts), chunk_size)]

    #with concurrent.futures.ThreadPoolExecutor() as executor:
    #    results = list(executor.map(spelling_corrections, chunks))
    with multiprocessing.Pool() as pool:
        results = pool.map(spelling_corrections, chunks)

    return [item for sublist in results for item in sublist]

def prepare_data_to_pandas():
    texts = []
    labels = []

    # to removes duplicate reviews 
    seen = set() 

    for data_category, review_categories_data in reviews_map_cleaned.items():
        for review_category, review_category_data in review_categories_data.items():
            for review in review_category_data:
                if not review.title:
                    if not review.review_text:
                        continue
                    full_review_text = review.review_text
                if not review.review_text:
                    full_review_text = review.title
                else:
                    full_review_text = f"{review.title} {review.review_text}"
                
                # check correctnesses
                if is_meaningful_review(full_review_text) == False:
                    continue
                
                # check duplicates
                if full_review_text in seen:
                    continue
                else:
                    seen.add(full_review_text)
    
                # check clean estimating
                review_mark = mark_review(review, review_category)
                if(review_mark == ReviewCategory.UNDEF):
                    continue
                
                texts.append(full_review_text)
                labels.append(1 if review_mark == ReviewCategory.POS else 0)
    
    return {'text': make_spelling_correction(texts), 'label': labels}

data_to_pandas = prepare_data_to_pandas()
df = pd.DataFrame(data_to_pandas)

df.to_csv('reviews_dataset2.csv', index=False)
# Out:
# [nltk_data] Downloading package words to /home/alex937/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
# Next chunk of corrections was finished
